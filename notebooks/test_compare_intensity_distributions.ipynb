# %% [markdown]
# # Test: `compare_intensity_distributions`
#
# Compares pixel intensity distributions between a style tomogram and a style-transferred tomogram via:
# - Summary statistics table
# - Normalized histogram overlay
# - Radially-averaged power spectrum (iPSD)

# %%
import sys
sys.path.insert(0, '..')

from faket_polnet.utils.utils import compare_intensity_distributions

# %% [markdown]
# ## Set paths
#
# - `style_path`: the real experimental tomogram used as style input (`.mrc`)
# - `faket_path`: the reconstructed style-transferred tomogram output by the pipeline (`.mrc`)

# %%
style_path = "/path/to/style_tomogram.mrc"
faket_path = "/path/to/faket_tomogram.mrc"

# %% [markdown]
# ## Run comparison

# %%
compare_intensity_distributions(style_path, faket_path)
